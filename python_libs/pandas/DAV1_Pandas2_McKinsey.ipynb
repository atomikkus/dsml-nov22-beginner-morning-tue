# %%
rename({"old_name": "new_name"}, axis=1, inplace=True)
rename(columns={"old_name": "new_name"})

# %%
df.drop(['col_name','col_name2'], axis=1, inplace=True)
df.drop(columns=[])

# %%
df['gdp'] = df['gdp_cap'] * df['population']

# %% [markdown]
# # Working with Rows

# %%
import pandas as pd
import numpy as np

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: c:\Users\prksh\Documents\GitHub\dsml-nov22-beginner-morning-tue\python_libs\pandas\mckinsey.csv
#
#   0%|          | 0.00/83.8k [00:00<?, ?B/s]
# 100%|██████████| 83.8k/83.8k [00:00<00:00, 166kB/s]
# 100%|██████████| 83.8k/83.8k [00:00<00:00, 166kB/s]

# %%
df = pd.read_csv('C:/Users/prksh/Documents/GitHub/dsml-nov22-beginner-morning-tue/python_libs/pandas/mckinsey.csv') # We are storing the data in df
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703], dtype=int64)

# %%
df.index = list(range(1, df.shape[0]+1)) # creating an index of same length
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index[1] # implicit index
# Out:
# 2

# %%
df.index = np.arange(1, df.shape[0]+1, dtype='float')# creating an index of same length
df
# Out:
#             country  year  population continent  life_exp     gdp_cap
# 1.0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2.0     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3.0     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4.0     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5.0     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...             ...   ...         ...       ...       ...         ...
# 1700.0     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701.0     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702.0     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703.0     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704.0     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
sample = df.head()
sample
# Out:
#          country  year  population continent  life_exp     gdp_cap
# 1.0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2.0  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3.0  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4.0  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5.0  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
sample.index = ['a','b','c','d','e']
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
sample.index[2]
# Out:
# 'c'

# %%
df.index = np.arange(1, df.shape[0]+1)# creating an index of same length
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
ser = df['country']
ser.head(20)
# Out:
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# Name: country, dtype: object

# %%
ser[12] # explicit index
# Out:
# 'Afghanistan'

# %%
ser[5:15] # implict indexing
# Out:
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# Name: country, dtype: object

# %% [markdown]
# with respect to a series
#
# 1. indexing refers to explicit index
# 2. slicing refers to implict index

# %%
df[:]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df[3:20]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 4   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 5   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 6   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 7   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 8   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 9   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 10  Afghanistan  1997    22227415      Asia    41.763   635.341351
# 11  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 12  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 13      Albania  1952     1282697    Europe    55.230  1601.056136
# 14      Albania  1957     1476505    Europe    59.280  1942.284244
# 15      Albania  1962     1728137    Europe    64.820  2312.888958
# 16      Albania  1967     1984060    Europe    66.220  2760.196931
# ...

# %%
df[5:15]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 6   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 7   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 8   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 9   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 10  Afghanistan  1997    22227415      Asia    41.763   635.341351
# 11  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 12  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 13      Albania  1952     1282697    Europe    55.230  1601.056136
# 14      Albania  1957     1476505    Europe    59.280  1942.284244
# 15      Albania  1962     1728137    Europe    64.820  2312.888958

# %% [markdown]
# df slicing: implicit index

# %% [markdown]
# #loc and iloc operations

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[1]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.loc[1:3]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 2, dtype: object

# %%
df.iloc[0:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.iloc[[1,10,100]]
# Out:
#          country  year  population continent  life_exp     gdp_cap
# 2    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 11   Afghanistan  2002    25268405      Asia    42.129  726.734055
# 101   Bangladesh  1972    70759295      Asia    45.252  630.233627

# %%
df.loc[[1,10,100]]
# Out:
#          country  year  population continent  life_exp     gdp_cap
# 1    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 10   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 100   Bangladesh  1967    62821884      Asia    43.453  721.186086

# %%
df.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1704, dtype: object

# %%
df.loc[1]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
temp = df.set_index("country")
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.loc['Afghanistan']
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
temp.reset_index()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.reset_index()
# Out:
#       index      country  year  population continent  life_exp     gdp_cap
# 0         1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         5  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# #Add new rows to a dataframe
#
# 1. append() function
# 2. .loc operation
# 3. iloc operation -> does not work ( indexError)

# %%
new_row = {'country': 'India', 'year': 2000,'life_exp':37.08,'population':13500000,'gdp_cap':900.23}
df.append(new_row)
# Out:
# C:\Users\prksh\AppData\Local\Temp\ipykernel_19280\2648827451.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\prksh\Documents\GitHub\dsml-nov22-beginner-morning-tue\python_libs\pandas\DAV1_Pandas2_McKinsey.ipynb Cell 44 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/prksh/Documents/GitHub/dsml-nov22-beginner-morning-tue/python_libs/pandas/DAV1_Pandas2_McKinsey.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> new_row = {'country': 'India', 'year': 2000,'life_exp':37.08,'population':13500000,'gdp_cap':900.23}
# ...

# %%
df.append(new_row, ignore_index=True)
# Out:
# C:\Users\prksh\AppData\Local\Temp\ipykernel_19280\2200271580.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row, ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# ...

# %%
df.shape[0]
# Out:
# 1704

# %%
df.loc[df.shape[0]] = ['India',2000 ,13500000,'Asia',37.08,900.23]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
#
# [1705 rows x 6 columns]

# %%
df.iloc[df.shape[0]] = ['India',200 ,1350000,'Asia',37.08,800.23]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-b100ec5dffee> in <cell line: 1>()
# ----> 1 df.iloc[df.shape[0]] = ['India',200 ,1350000,'Asia',37.08,800.23]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     813             key = com.apply_if_callable(key, self.obj)
#     814         indexer = self._get_setitem_indexer(key)
# --> 815         self._has_valid_setitem_indexer(key)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1516             elif is_integer(i):
#    1517                 if i >= len(ax):
# -> 1518                     raise IndexError("iloc cannot enlarge its target object")
#    1519             elif isinstance(i, dict):
# ...

# %%
df.iloc[-1] # update the last row and not create a new row
# Out:
# country          India
# year              2000
# population    13500000
# continent         Asia
# life_exp         37.08
# gdp_cap         900.23
# Name: 1704, dtype: object

# %%
df.iloc[-2] = ['India',2000 ,13500000,'Asia',37.08,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
#
# [1705 rows x 6 columns]

# %% [markdown]
# NOTE : both loc and iloc can be used to update existing rows. But only loc can be used to add new rows to dataframe

# %%
df = df.drop(3, axis = 0)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
#
# [1704 rows x 6 columns]

# %%
df.loc[4]
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# country       Afghanistan
# year                 1977
# population       14880372
# continent            Asia
# life_exp           38.438
# gdp_cap         786.11336
# Name: 5, dtype: object

# %%
df.drop([1,2,4], axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7     Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8     Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        India  2000    13500000      Asia    37.080  900.230000
#
# [1701 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# duplicated data

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# Length: 1704, dtype: bool

# %%
df.loc[df.duplicated()] # get the duplicate row
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1703   India  2000    13500000      Asia     37.08   900.23

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1698     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1699     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702        India  2000    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df.drop_duplicates(keep = 'first')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1698     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1699     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702        India  2000    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df.drop_duplicates(keep = 'last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1698     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1699     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703        India  2000    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df.drop_duplicates(keep = False) # if you don't want to retain any duplicates
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1697     Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1698     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1699     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
#
# [1702 rows x 6 columns]

# %% [markdown]
# iloc for both rows and columns

# %% [markdown]
# get the first 1 rows and 2,3,4th column

# %%
df.iloc[0:5 , 1:4]
# Out:
#    year  population continent
# 0  1952     8425333      Asia
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1972    13079460      Asia
# 4  1977    14880372      Asia

# %%
df.iloc[0:5 , [-1]]
# Out:
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  739.981106
# 4  786.113360

# %%
df.loc[0:4 , ['year','population','continent']]
# Out:
#    year  population continent
# 0  1952     8425333      Asia
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1972    13079460      Asia
# 4  1977    14880372      Asia

# %%
df.loc[0:4 , 'year': 'continent'] # slicing operation on loc
# Out:
#    year  population continent
# 0  1952     8425333      Asia
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1972    13079460      Asia
# 4  1977    14880372      Asia

# %%
df.iloc[[0,10,100], [0,2,3]]
# Out:
#          country  population continent
# 0    Afghanistan     8425333      Asia
# 10   Afghanistan    31889923      Asia
# 100   Bangladesh    80428306      Asia

# %% [markdown]
# step slicing

# %%
df.iloc[1:10:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
df.loc[0:10:2]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2007    31889923      Asia    43.828  974.580338

# %% [markdown]
# mathematical operations directly on your columns

# %%
le = df['life_exp']

# %%
type(le)
# Out:
# pandas.core.series.Series

# %%
le.mean()
# Out:
# 59.47247516431925

# %%
le.count()
# Out:
# 1704

# %%
le.sum()
# Out:
# 101341.09768

# %% [markdown]
# sort dataframe

# %%
df.sort_values('life_exp')
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values('life_exp', ascending=False) # descending order
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1031        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 70           Australia  2007    20434176   Oceania    81.235  34435.367440
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'], ascending=[False, True])
# Out:
#            country  year  population continent  life_exp       gdp_cap
# 1462     Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1042    Mozambique  2007    19951656    Africa    42.082    823.685621
# 1690        Zambia  2007    11746035    Africa    42.384   1271.211593
# 1354  Sierra Leone  2007     6144562    Africa    42.568    862.540756
# 886        Lesotho  2007     2012649    Africa    42.592   1569.331442
# ...            ...   ...         ...       ...       ...           ...
# 407        Denmark  1952     4334000    Europe    70.780   9692.385245
# 1463        Sweden  1952     7124673    Europe    71.860   8527.844662
# 1079   Netherlands  1952    10381988    Europe    72.130   8941.571858
# 683        Iceland  1952      147962    Europe    72.490   7267.688428
# 1139        Norway  1952     3327728    Europe    72.670  10095.421720
#
# [1704 rows x 6 columns]

# %%
df[['country','continent']].duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1699     True
# 1700     True
# 1701     True
# 1702     True
# 1703     True
# Length: 1704, dtype: bool

# %%
df.set_index(['country','continent'])
# Out:
#                        year  population  life_exp     gdp_cap
# country     continent
# Afghanistan Asia       1952     8425333    28.801  779.445314
#             Asia       1957     9240934    30.332  820.853030
#             Asia       1962    10267083    31.997  853.100710
#             Asia       1972    13079460    36.088  739.981106
#             Asia       1977    14880372    38.438  786.113360
# ...                     ...         ...       ...         ...
# Zimbabwe    Africa     1992    10704340    60.377  693.420786
#             Africa     1997    11404948    46.809  792.449960
#             Africa     2002    11926563    39.989  672.038623
# India       Asia       2000    13500000    37.080  900.230000
#             Asia       2000    13500000    37.080  900.230000
#
# [1704 rows x 4 columns]
